# %% [markdown]
# <a href="https://colab.research.google.com/github/jsjj10002/Deep-learning-study/blob/main/ch2example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=100
print(x)
# Out:
# 100

# %%
x=100
print(x)
x=200
print(x)
# Out:
# 100
# 200

# %%
x=100
y=1200
sum = x+y
name = "홍길동"
address = " 서울시 종로구 1번지"

# %%
print(x);print(y);print(sum)
# Out:
# 100
# 1200
# 1300

# %%
print(name)
print(address)
# Out:
# 홍길동
#  서울시 종로구 1번지

# %%
A=17
type(A)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print(type(17.5))
B='python'
print(type(B))

# %%
type(A)
# Out:
# int

# %%
type(B)
# Out:
# str

# %%
type(17.5)
# Out:
# float

# %%
type([1,2,3,4])
# Out:
# list

# %%
a=True ;type(a)
# Out:
# bool

# %%
a=bool(1);type(a)
# Out:
# bool

# %%
type(int(a))
# Out:
# int

# %%
x= int(input("input first real number"))
y= int(input("input second real number"))
sum=x+y;print("x+y=",sum)
# Out:
# input first real number100
# input second real number200
# x+y= 300

# %%
name=str(input('input your name: '))
print(name,', hello')
# Out:
# input your name: a
# a , hello

# %%
name=input("input your name:")

height=int(input("inout yuor height:"))
weight=int(input("input yuor weight:"))
bmi=weight/(height**2)
print("%s's bmi is %02f"%(name, bmi))
# Out:
# input your name:js
# inout yuor height:177
# input yuor weight:95
# js's bmi is 0.003032
